# %% [raw]
# ---
# title: "Training my first ML model"
# description: "Link to fast.ai's free course: https://course.fast.ai"
# author: "Kazuki Aoyama"
# date: "2026-04-30"
# categories: [ML, Python, Fastai]
# jupyter: blog_310
# ---

# %% [markdown]
# I created a man/woman identifyer based on the top photos that came up in the search results on Bing:
# [Link to Kaggle](https://www.kaggle.com/code/aokazu/is-it-a-man-or-woman)
#
# # Top 3 Learning Outcomes
#
# ## 1. The relationship between model training time and performance is not linear.
# - Over fitting data (memorization of data)
# - Accuracy for the training data goes up, but the testing data accuracy goes down.
# ## 2.
#
# # Further Questions
# -
