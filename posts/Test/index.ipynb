# %% [raw]
# ---
# title: "Title of Your Post"
# description: "A quick summary for the blog home page."
# author: "Kazuki Aoyama"
# date: "2026-04-27"
# categories: [ML, Python, Fastai]
# jupyter: blog_310
# ---

# %% [markdown]
# # This is a test

# %% [markdown]
# ## To see

# %% [markdown]
# ### How this thing

# %% [markdown]
# **Works**

# %%
print('Now, is this working?')
# Out:
# Now, is this working?
